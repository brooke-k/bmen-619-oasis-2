# %% [markdown]
# # Setup

# %%
import os
import shutil
import re
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import nibabel as nib
import matplotlib as mpl
import matplotlib.pyplot as plt

load_dotenv()
# Out:
# True

# %% [markdown]
# Helper functions for making it easier to visualize model training

# %%
def progressCount(current:int, total:int, title=""):
  """
  Prints a loading progress bar.

  Parameters:
    current (int): Current number out of total
    total (int): Total
    title (str) : (Optional) Title to appear alongside loading bar. Defaults to no title.
  """
  num_bars = 20
  pcent = 1.*current/total
  blocks = int((num_bars * pcent) - (num_bars * pcent) % 1)
  lines = num_bars - blocks
  print(f'{title} ┝\033[92m{blocks*"█"}\033[0m{lines*"━"}┥\t{current}/{total}\t({100*pcent:.1f}%)')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Convert Raw Data to .nii
#
# Original OASIS-2 values are provided as .nifti.img and .nifiti.hdr pairs. Each pair is converted to a single .nii file.
#
# .env variables:
#
# - `MOVE_RAW` -- if 1, original OASIS-2 files will be converted to .nii files. Otherwise, this function is ignored.
# - `RAW` -- The source directory containing the original OASIS-2 files
# - `NII` -- The destination directory to hold the converted .nii files

# %%
raw_dir = os.getenv("RAW")
nii_dir = os.getenv("NII")

def moveRaw(raw_dir, nii_dir):
    """
    Function for converting files in the raw OASIS-2 directory to .nii, then moving them to the specified 'nii_dir' directory

    Parameters:
        raw_dir (str): Source directory containing the raw OASIS-2 files
        nii_dir (str): Destination directory to copy the converted .nii files into

    Returns:
        None
    """


    i=0
    if not os.path.exists(nii_dir):
        os.makedirs(nii_dir)

    # Regex pattern to get the MRI id and visit number
    rawDirPat = r"(?:[\W\S]+?)OAS2_([0-9]{4})_MR([0-2]{1})/RAW"
    for root, dir, files in os.walk(raw_dir):
        r_match = re.findall(rawDirPat, root)
        if len(r_match) > 0:
            subID = r_match[0][0]
            session = r_match[0][1]
            new_name = f"{subID}_{session}"
            for f in files:
                # Get file extension
                fname, fext = os.path.splitext(f)
                # If the file is a .img, it should be converted to .nii
                if fext == ".img":
                    # Get mpr number from file name
                    f_match = re.findall(r"mpr-([0-2]{1}).nifti", fname)
                    if len(f_match) > 0:
                        f_num = f_match[0]

                        # Get full path of .img file
                        img_name = os.path.join(root, (fname + ".img"))

                        # Create new name for .nii file and put it in the right path
                        nii_name = os.path.join(
                            nii_dir, f"OAS2_{subID}_MR{session}_F{f_num}.nifti.nii"
                        )

                        # Load .img image using nibabel
                        img = nib.load(img_name)

                        # Save .nii image in nii directory with new name
                        nib.save(img, nii_name)
                        progressCount(i, 587, "Converted to .nii")

                        i+=1



if os.getenv("MOVERAW")=="1":
    moveRaw(raw_dir, nii_dir)
# Out:
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	0/587	(0.0%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	1/587	(0.2%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	2/587	(0.3%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	3/587	(0.5%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	4/587	(0.7%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	5/587	(0.9%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	6/587	(1.0%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	7/587	(1.2%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	8/587	(1.4%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	9/587	(1.5%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	10/587	(1.7%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	11/587	(1.9%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	12/587	(2.0%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	13/587	(2.2%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	14/587	(2.4%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	15/587	(2.6%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	16/587	(2.7%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	17/587	(2.9%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	18/587	(3.1%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	19/587	(3.2%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥	20/587	(3.4%)
# Converted to .nii ┝━━━━━━━━━━━━━━━━━━━━┥
)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	271/587	(46.2%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	272/587	(46.3%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	273/587	(46.5%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	274/587	(46.7%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	275/587	(46.8%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	276/587	(47.0%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	277/587	(47.2%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	278/587	(47.4%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	279/587	(47.5%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	280/587	(47.7%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	281/587	(47.9%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	282/587	(48.0%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	283/587	(48.2%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	284/587	(48.4%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	285/587	(48.6%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	286/587	(48.7%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	287/587	(48.9%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	288/587	(49.1%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	289/587	(49.2%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	290/587	(49.4%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	291/587	(49.6%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	292/587	(49.7%)
# Converted to .nii ┝█████████━━━━━━━━━━━┥	293/587	(49.9%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	294/587	(50.1%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	295/587	(50.3%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	296/587	(50.4%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	297/587	(50.6%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	298/587	(50.8%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	299/587	(50.9%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	300/587	(51.1%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	301/587	(51.3%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	302/587	(51.4%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	303/587	(51.6%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	304/587	(51.8%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	305/587	(52.0%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	306/587	(52.1%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	307/587	(52.3%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	308/587	(52.5%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	309/587	(52.6%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	310/587	(52.8%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	311/587	(53.0%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	312/587	(53.2%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	313/587	(53.3%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	314/587	(53.5%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	315/587	(53.7%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	316/587	(53.8%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	317/587	(54.0%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	318/587	(54.2%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	319/587	(54.3%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	320/587	(54.5%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	321/587	(54.7%)
# Converted to .nii ┝██████████━━━━━━━━━━┥	322/587	(54.9%)
# Converted to .nii ┝███████████━━━━━━━━━┥	323/587	(55.0%)
# Converted to .nii ┝███████████━━━━━━━━━┥	324/587	(55.2%)
# Converted to .nii ┝███████████━━━━━━━━━┥	325/587	(55.4%)
# Converted to .nii ┝███████████━━━━━━━━━┥	326/587	(55.5%)
# Converted to .nii ┝███████████━━━━━━━━━┥	327/587	(55.7%)
# Converted to .nii ┝███████████━━━━━━━━━┥	328/587	(55.9%)
# Converted to .nii ┝███████████━━━━━━━━━┥	329/587	(56.0%)
# Converted to .nii ┝███████████━━━━━━━━━┥	330/587	(56.2%)
# Converted to .nii ┝███████████━━━━━━━━━┥	331/587	(56.4%)
# Converted to .nii ┝███████████━━━━━━━━━┥	332/587	(56.6%)
# Converted to .nii ┝███████████━━━━━━━━━┥	333/587	(56.7%)
# Converted to .nii ┝███████████━━━━━━━━━┥	334/587	(56.9%)
# Converted to .nii ┝███████████━━━━━━━━━┥	335/587	(57.1%)
# Converted to .nii ┝███████████━━━━━━━━━┥	336/587	(57.2%)
# Converted to .nii ┝███████████━━━━━━━━━┥	337/587	(57.4%)
# Converted to .nii ┝███████████━━━━━━━━━┥	338/587	(57.6%)
# Converted to .nii ┝███████████━━━━━━━━━┥	339/587	(57.8%)
# Converted to .nii ┝███████████━━━━━━━━━┥	340/587	(57.9%)
# Converted to .nii ┝███████████━━━━━━━━━┥	341/587	(58.1%)
# Converted to .nii ┝███████████━━━━━━━━━┥	342/587	(58.3%)
# Converted to .nii ┝███████████━━━━━━━━━┥	343/587	(58.4%)
# Converted to .nii ┝███████████━━━━━━━━━┥	344/587	(58.6%)
# Converted to .nii ┝███████████━━━━━━━━━┥	345/587	(58.8%)
# Converted to .nii ┝███████████━━━━━━━━━┥	346/587	(58.9%)
# Converted to .nii ┝███████████━━━━━━━━━┥	347/587	(59.1%)
# Converted to .nii ┝███████████━━━━━━━━━┥	348/587	(59.3%)
# Converted to .nii ┝███████████━━━━━━━━━┥	349/587	(59.5%)
# Converted to .nii ┝███████████━━━━━━━━━┥	350/587	(59.6%)
# Converted to .nii ┝███████████━━━━━━━━━┥	351/587	(59.8%)
# Converted to .nii ┝███████████━━━━━━━━━┥	352/587	(60.0%)
# Converted to .nii ┝████████████━━━━━━━━┥	353/587	(60.1%)
# Converted to .nii ┝████████████━━━━━━━━┥	354/587	(60.3%)
# Converted to .nii ┝████████████━━━━━━━━┥	355/587	(60.5%)
# Converted to .nii ┝████████████━━━━━━━━┥	356/587	(60.6%)
# Converted to .nii ┝████████████━━━━━━━━┥	357/587	(60.8%)
# Converted to .nii ┝████████████━━━━━━━━┥	358/587	(61.0%)
# Converted to .nii ┝████████████━━━━━━━━┥	359/587	(61.2%)
# Converted to .nii ┝████████████━━━━━━━━┥	360/587	(61.3%)
# Converted to .nii ┝████████████━━━━━━━━┥	361/587	(61.5%)
# Converted to .nii ┝████████████━━━━━━━━┥	362/587	(61.7%)
# Converted to .nii ┝████████████━━━━━━━━┥	363/587	(61.8%)
# Converted to .nii ┝████████████━━━━━━━━┥	364/587	(62.0%)
# Converted to .nii ┝████████████━━━━━━━━┥	365/587	(62.2%)
# Converted to .nii ┝████████████━━━━━━━━┥	366/587	(62.4%)
# Converted to .nii ┝████████████━━━━━━━━┥	367/587	(62.5%)
# Converted to .nii ┝████████████━━━━━━━━┥	368/587	(62.7%)
# Converted to .nii ┝████████████━━━━━━━━┥	369/587	(62.9%)
# Converted to .nii ┝████████████━━━━━━━━┥	370/587	(63.0%)
# Converted to .nii ┝████████████━━━━━━━━┥	371/587	(63.2%)
# Converted to .nii ┝████████████━━━━━━━━┥	372/587	(63.4%)
# Converted to .nii ┝████████████━━━━━━━━┥	373/587	(63.5%)
# Converted to .nii ┝████████████━━━━━━━━┥	374/587	(63.7%)
# Converted to .nii ┝████████████━━━━━━━━┥	375/587	(63.9%)
# Converted to .nii ┝████████████━━━━━━━━┥	376/587	(64.1%)
# Converted to .nii ┝████████████━━━━━━━━┥	377/587	(64.2%)
# Converted to .nii ┝████████████━━━━━━━━┥	378/587	(64.4%)
# Converted to .nii ┝████████████━━━━━━━━┥	379/587	(64.6%)
# Converted to .nii ┝████████████━━━━━━━━┥	380/587	(64.7%)
# Converted to .nii ┝████████████━━━━━━━━┥	381/587	(64.9%)
# Converted to .nii ┝█████████████━━━━━━━┥	382/587	(65.1%)
# Converted to .nii ┝█████████████━━━━━━━┥	383/587	(65.2%)
# Converted to .nii ┝█████████████━━━━━━━┥	384/587	(65.4%)
# Converted to .nii ┝█████████████━━━━━━━┥	385/587	(65.6%)
# Converted to .nii ┝█████████████━━━━━━━┥	386/587	(65.8%)
# Converted to .nii ┝█████████████━━━━━━━┥	387/587	(65.9%)
# Converted to .nii ┝█████████████━━━━━━━┥	388/587	(66.1%)
# Converted to .nii ┝█████████████━━━━━━━┥	389/587	(66.3%)
# Converted to .nii ┝█████████████━━━━━━━┥	390/587	(66.4%)
# Converted to .nii ┝█████████████━━━━━━━┥	391/587	(66.6%)
# Converted to .nii ┝█████████████━━━━━━━┥	392/587	(66.8%)
# Converted to .nii ┝█████████████━━━━━━━┥	393/587	(67.0%)
# Converted to .nii ┝█████████████━━━━━━━┥	394/587	(67.1%)
# Converted to .nii ┝█████████████━━━━━━━┥	395/587	(67.3%)
# Converted to .nii ┝█████████████━━━━━━━┥	396/587	(67.5%)
# Converted to .nii ┝█████████████━━━━━━━┥	397/587	(67.6%)
# Converted to .nii ┝█████████████━━━━━━━┥	398/587	(67.8%)
# Converted to .nii ┝█████████████━━━━━━━┥	399/587	(68.0%)
# Converted to .nii ┝█████████████━━━━━━━┥	400/587	(68.1%)
# Converted to .nii ┝█████████████━━━━━━━┥	401/587	(68.3%)
# Converted to .nii ┝█████████████━━━━━━━┥	402/587	(68.5%)
# Converted to .nii ┝█████████████━━━━━━━┥	403/587	(68.7%)
# Converted to .nii ┝█████████████━━━━━━━┥	404/587	(68.8%)
# Converted to .nii ┝█████████████━━━━━━━┥	405/587	(69.0%)
# Converted to .nii ┝█████████████━━━━━━━┥	406/587	(69.2%)
# Converted to .nii ┝█████████████━━━━━━━┥	407/587	(69.3%)
# Converted to .nii ┝█████████████━━━━━━━┥	408/587	(69.5%)
# Converted to .nii ┝█████████████━━━━━━━┥	409/587	(69.7%)
# Converted to .nii ┝█████████████━━━━━━━┥	410/587	(69.8%)
# Converted to .nii ┝██████████████━━━━━━┥	411/587	(70.0%)
# Converted to .nii ┝██████████████━━━━━━┥	412/587	(70.2%)
# Converted to .nii ┝██████████████━━━━━━┥	413/587	(70.4%)
# Converted to .nii ┝██████████████━━━━━━┥	414/587	(70.5%)
# Converted to .nii ┝██████████████━━━━━━┥	415/587	(70.7%)
# Converted to .nii ┝██████████████━━━━━━┥	416/587	(70.9%)
# Converted to .nii ┝██████████████━━━━━━┥	417/587	(71.0%)
# Converted to .nii ┝██████████████━━━━━━┥	418/587	(71.2%)
# Converted to .nii ┝██████████████━━━━━━┥	419/587	(71.4%)
# Converted to .nii ┝██████████████━━━━━━┥	420/587	(71.6%)
# Converted to .nii ┝██████████████━━━━━━┥	421/587	(71.7%)
# Converted to .nii ┝██████████████━━━━━━┥	422/587	(71.9%)
# Converted to .nii ┝██████████████━━━━━━┥	423/587	(72.1%)
# Converted to .nii ┝██████████████━━━━━━┥	424/587	(72.2%)
# Converted to .nii ┝██████████████━━━━━━┥	425/587	(72.4%)
# Converted to .nii ┝██████████████━━━━━━┥	426/587	(72.6%)
# Converted to .nii ┝██████████████━━━━━━┥	427/587	(72.7%)
# Converted to .nii ┝██████████████━━━━━━┥	428/587	(72.9%)
# Converted to .nii ┝██████████████━━━━━━┥	429/587	(73.1%)
# Converted to .nii ┝██████████████━━━━━━┥	430/587	(73.3%)
# Converted to .nii ┝██████████████━━━━━━┥	431/587	(73.4%)
# Converted to .nii ┝██████████████━━━━━━┥	432/587	(73.6%)
# Converted to .nii ┝██████████████━━━━━━┥	433/587	(73.8%)
# Converted to .nii ┝██████████████━━━━━━┥	434/587	(73.9%)
# Converted to .nii ┝██████████████━━━━━━┥	435/587	(74.1%)
# Converted to .nii ┝██████████████━━━━━━┥	436/587	(74.3%)
# Converted to .nii ┝██████████████━━━━━━┥	437/587	(74.4%)
# Converted to .nii ┝██████████████━━━━━━┥	438/587	(74.6%)
# Converted to .nii ┝██████████████━━━━━━┥	439/587	(74.8%)
# Converted to .nii ┝██████████████━━━━━━┥	440/587	(75.0%)
# Converted to .nii ┝███████████████━━━━━┥	441/587	(75.1%)
# Converted to .nii ┝███████████████━━━━━┥	442/587	(75.3%)
# Converted to .nii ┝███████████████━━━━━┥	443/587	(75.5%)
# Converted to .nii ┝███████████████━━━━━┥	444/587	(75.6%)
# Converted to .nii ┝███████████████━━━━━┥	445/587	(75.8%)
# Converted to .nii ┝███████████████━━━━━┥	446/587	(76.0%)
# Converted to .nii ┝███████████████━━━━━┥	447/587	(76.1%)
# Converted to .nii ┝███████████████━━━━━┥	448/587	(76.3%)
# Converted to .nii ┝███████████████━━━━━┥	449/587	(76.5%)
# Converted to .nii ┝███████████████━━━━━┥	450/587	(76.7%)
# Converted to .nii ┝███████████████━━━━━┥	451/587	(76.8%)
# Converted to .nii ┝███████████████━━━━━┥	452/587	(77.0%)
# Converted to .nii ┝███████████████━━━━━┥	453/587	(77.2%)
# Converted to .nii ┝███████████████━━━━━┥	454/587	(77.3%)
# Converted to .nii ┝███████████████━━━━━┥	455/587	(77.5%)
# Converted to .nii ┝███████████████━━━━━┥	456/587	(77.7%)
# Converted to .nii ┝███████████████━━━━━┥	457/587	(77.9%)
# Converted to .nii ┝███████████████━━━━━┥	458/587	(78.0%)
# Converted to .nii ┝███████████████━━━━━┥	459/587	(78.2%)
# Converted to .nii ┝███████████████━━━━━┥	460/587	(78.4%)
# Converted to .nii ┝███████████████━━━━━┥	461/587	(78.5%)
# Converted to .nii ┝███████████████━━━━━┥	462/587	(78.7%)
# Converted to .nii ┝███████████████━━━━━┥	463/587	(78.9%)
# Converted to .nii ┝███████████████━━━━━┥	464/587	(79.0%)
# Converted to .nii ┝███████████████━━━━━┥	465/587	(79.2%)
# Converted to .nii ┝███████████████━━━━━┥	466/587	(79.4%)
# Converted to .nii ┝███████████████━━━━━┥	467/587	(79.6%)
# Converted to .nii ┝███████████████━━━━━┥	468/587	(79.7%)
# Converted to .nii ┝███████████████━━━━━┥	469/587	(79.9%)
# Converted to .nii ┝████████████████━━━━┥	470/587	(80.1%)
# Converted to .nii ┝████████████████━━━━┥	471/587	(80.2%)
# Converted to .nii ┝████████████████━━━━┥	472/587	(80.4%)
# Converted to .nii ┝████████████████━━━━┥	473/587	(80.6%)
# Converted to .nii ┝████████████████━━━━┥	474/587	(80.7%)
# Converted to .nii ┝████████████████━━━━┥	475/587	(80.9%)
# Converted to .nii ┝████████████████━━━━┥	476/587	(81.1%)
# Converted to .nii ┝████████████████━━━━┥	477/587	(81.3%)
# Converted to .nii ┝████████████████━━━━┥	478/587	(81.4%)
# Converted to .nii ┝████████████████━━━━┥	479/587	(81.6%)
# Converted to .nii ┝████████████████━━━━┥	480/587	(81.8%)
# Converted to .nii ┝████████████████━━━━┥	481/587	(81.9%)
# Converted to .nii ┝████████████████━━━━┥	482/587	(82.1%)
# Converted to .nii ┝████████████████━━━━┥	483/587	(82.3%)
# Converted to .nii ┝████████████████━━━━┥	484/587	(82.5%)
# Converted to .nii ┝████████████████━━━━┥	485/587	(82.6%)
# Converted to .nii ┝████████████████━━━━┥	486/587	(82.8%)
# Converted to .nii ┝████████████████━━━━┥	487/587	(83.0%)
# Converted to .nii ┝████████████████━━━━┥	488/587	(83.1%)
# Converted to .nii ┝████████████████━━━━┥	489/587	(83.3%)
# Converted to .nii ┝████████████████━━━━┥	490/587	(83.5%)
# Converted to .nii ┝████████████████━━━━┥	491/587	(83.6%)
# Converted to .nii ┝████████████████━━━━┥	492/587	(83.8%)
# Converted to .nii ┝████████████████━━━━┥	493/587	(84.0%)
# Converted to .nii ┝████████████████━━━━┥	494/587	(84.2%)
# Converted to .nii ┝████████████████━━━━┥	495/587	(84.3%)
# Converted to .nii ┝████████████████━━━━┥	496/587	(84.5%)
# Converted to .nii ┝████████████████━━━━┥	497/587	(84.7%)
# Converted to .nii ┝████████████████━━━━┥	498/587	(84.8%)
# Converted to .nii ┝█████████████████━━━┥	499/587	(85.0%)
# Converted to .nii ┝█████████████████━━━┥	500/587	(85.2%)
# Converted to .nii ┝█████████████████━━━┥	501/587	(85.3%)
# Converted to .nii ┝█████████████████━━━┥	502/587	(85.5%)
# Converted to .nii ┝█████████████████━━━┥	503/587	(85.7%)
# Converted to .nii ┝█████████████████━━━┥	504/587	(85.9%)
# Converted to .nii ┝█████████████████━━━┥	505/587	(86.0%)
# Converted to .nii ┝█████████████████━━━┥	506/587	(86.2%)
# Converted to .nii ┝█████████████████━━━┥	507/587	(86.4%)
# Converted to .nii ┝█████████████████━━━┥	508/587	(86.5%)
# Converted to .nii ┝█████████████████━━━┥	509/587	(86.7%)
# Converted to .nii ┝█████████████████━━━┥	510/587	(86.9%)
# Converted to .nii ┝█████████████████━━━┥	511/587	(87.1%)
# Converted to .nii ┝█████████████████━━━┥	512/587	(87.2%)
# Converted to .nii ┝█████████████████━━━┥	513/587	(87.4%)
# Converted to .nii ┝█████████████████━━━┥	514/587	(87.6%)
# Converted to .nii ┝█████████████████━━━┥	515/587	(87.7%)
# Converted to .nii ┝█████████████████━━━┥	516/587	(87.9%)
# Converted to .nii ┝█████████████████━━━┥	517/587	(88.1%)
# Converted to .nii ┝█████████████████━━━┥	518/587	(88.2%)
# Converted to .nii ┝█████████████████━━━┥	519/587	(88.4%)
# Converted to .nii ┝█████████████████━━━┥	520/587	(88.6%)
# Converted to .nii ┝█████████████████━━━┥	521/587	(88.8%)
# Converted to .nii ┝█████████████████━━━┥	522/587	(88.9%)
# Converted to .nii ┝█████████████████━━━┥	523/587	(89.1%)
# Converted to .nii ┝█████████████████━━━┥	524/587	(89.3%)
# Converted to .nii ┝█████████████████━━━┥	525/587	(89.4%)
# Converted to .nii ┝█████████████████━━━┥	526/587	(89.6%)
# Converted to .nii ┝█████████████████━━━┥	527/587	(89.8%)
# Converted to .nii ┝█████████████████━━━┥	528/587	(89.9%)
# Converted to .nii ┝██████████████████━━┥	529/587	(90.1%)
# Converted to .nii ┝██████████████████━━┥	530/587	(90.3%)
# Converted to .nii ┝██████████████████━━┥	531/587	(90.5%)
# Converted to .nii ┝██████████████████━━┥	532/587	(90.6%)
# Converted to .nii ┝██████████████████━━┥	533/587	(90.8%)
# Converted to .nii ┝██████████████████━━┥	534/587	(91.0%)
# Converted to .nii ┝██████████████████━━┥	535/587	(91.1%)
# Converted to .nii ┝██████████████████━━┥	536/587	(91.3%)
# Converted to .nii ┝██████████████████━━┥	537/587	(91.5%)
# Converted to .nii ┝██████████████████━━┥	538/587	(91.7%)
# Converted to .nii ┝██████████████████━━┥	539/587	(91.8%)
# Converted to .nii ┝██████████████████━━┥	540/587	(92.0%)
# Converted to .nii ┝██████████████████━━┥	541/587	(92.2%)
# Converted to .nii ┝██████████████████━━┥	542/587	(92.3%)
# Converted to .nii ┝██████████████████━━┥	543/587	(92.5%)
# Converted to .nii ┝██████████████████━━┥	544/587	(92.7%)
# Converted to .nii ┝██████████████████━━┥	545/587	(92.8%)
# Converted to .nii ┝██████████████████━━┥	546/587	(93.0%)
# Converted to .nii ┝██████████████████━━┥	547/587	(93.2%)
# Converted to .nii ┝██████████████████━━┥	548/587	(93.4%)
# Converted to .nii ┝██████████████████━━┥	549/587	(93.5%)
# Converted to .nii ┝██████████████████━━┥	550/587	(93.7%)
# Converted to .nii ┝██████████████████━━┥	551/587	(93.9%)
# Converted to .nii ┝██████████████████━━┥	552/587	(94.0%)
# Converted to .nii ┝██████████████████━━┥	553/587	(94.2%)
# Converted to .nii ┝██████████████████━━┥	554/587	(94.4%)
# Converted to .nii ┝██████████████████━━┥	555/587	(94.5%)
# Converted to .nii ┝██████████████████━━┥	556/587	(94.7%)
# Converted to .nii ┝██████████████████━━┥	557/587	(94.9%)
# Converted to .nii ┝███████████████████━┥	558/587	(95.1%)
# Converted to .nii ┝███████████████████━┥	559/587	(95.2%)
# Converted to .nii ┝███████████████████━┥	560/587	(95.4%)
# Converted to .nii ┝███████████████████━┥	561/587	(95.6%)
# Converted to .nii ┝███████████████████━┥	562/587	(95.7%)
# Converted to .nii ┝███████████████████━┥	563/587	(95.9%)
# Converted to .nii ┝███████████████████━┥	564/587	(96.1%)
# Converted to .nii ┝███████████████████━┥	565/587	(96.3%)
# Converted to .nii ┝███████████████████━┥	566/587	(96.4%)
# Converted to .nii ┝███████████████████━┥	567/587	(96.6%)
# Converted to .nii ┝███████████████████━┥	568/587	(96.8%)
# Converted to .nii ┝███████████████████━┥	569/587	(96.9%)
# Converted to .nii ┝███████████████████━┥	570/587	(97.1%)
# Converted to .nii ┝███████████████████━┥	571/587	(97.3%)
# Converted to .nii ┝███████████████████━┥	572/587	(97.4%)
# Converted to .nii ┝███████████████████━┥	573/587	(97.6%)
# Converted to .nii ┝███████████████████━┥	574/587	(97.8%)
# Converted to .nii ┝███████████████████━┥	575/587	(98.0%)
# Converted to .nii ┝███████████████████━┥	576/587	(98.1%)
# Converted to .nii ┝███████████████████━┥	577/587	(98.3%)
# Converted to .nii ┝███████████████████━┥	578/587	(98.5%)
# Converted to .nii ┝███████████████████━┥	579/587	(98.6%)
# Converted to .nii ┝███████████████████━┥	580/587	(98.8%)
# Converted to .nii ┝███████████████████━┥	581/587	(99.0%)
# Converted to .nii ┝███████████████████━┥	582/587	(99.1%)
# Converted to .nii ┝███████████████████━┥	583/587	(99.3%)
# Converted to .nii ┝███████████████████━┥	584/587	(99.5%)
# Converted to .nii ┝███████████████████━┥	585/587	(99.7%)
# Converted to .nii ┝███████████████████━┥	586/587	(99.8%)
# Converted to .nii ┝████████████████████┥	587/587	(100.0%)

# %% [markdown]
# Move all files to one directory

# %% [markdown]
# ## Convert .nii Files to .jpg

# %% [markdown]
# Functions for converting to .jpg

# %%
from sklearn.model_selection import train_test_split

def makeTVTSplit(df:pd.DataFrame, training=0.8, testing=0.12):
  """
  Makes a new training, testing, and validation split and returns a dataframe containing the split set for each sample. The portion of samples in the validation set is 1 - training - testing. Default size of validation set is 0.08 (8%)

  Parameters:
    df (pandas.DataFrame): DataFrame containing the samples to be split into different sets
    training (float): Portion of the samples to be put into the training set. Default is 0.8 (80%)
    testing (float): Portion of the samples to be put into the validation set. Default is 0.12 (12%)

  Returns:
    out (pandas.DataFrame) : Copy of the DataFrame provided, with the splitset for each sample added in the column "Split"
  """
  validation = (1.0-training-testing)/(1.0-training)

  x_train, x_temp, y_train, y_temp = train_test_split(df.drop(columns=["Group"]), df["Group"], test_size=1-training, stratify=df[['Group',"Sex_F"]])

  strat = pd.DataFrame(x_temp)
  strat["Group"] = y_temp

  x_test, x_val, y_test, y_val = train_test_split(x_temp, y_temp, stratify=strat[['Group',"Sex_F"]],test_size=validation)
  train = x_train.copy(deep=True)
  train["Split"] = ["train"]*train.shape[0]
  train["Group"] = y_train.values

  validate = x_val.copy(deep=True)
  validate["Split"] = ["validate"]*validate.shape[0]
  validate["Group"] = y_val.values

  test = x_test.copy(deep=True)
  test["Split"] = ["test"]*test.shape[0]
  test["Group"] = y_test.values
  print(f"Split:")
  print(f'\tTest: {len(test)}')
  print(f'\tTrain: {len(train)}')
  print(f'\tValidate: {len(validate)}')

  df_new = pd.merge(train, test, how="outer")
  df_new = pd.merge(df_new, validate, how="outer")

  return df_new

def getImgGroup(filename, df):
  """
   Get the group (demented or nondemented) of the sample with the filename provided

   Parameters:
      filename (str): Name of the file
      df (pandas.DataFrame): DataFrame containing the list of MRI IDs and their groups

   Returns:
      out (int): 0 if nondemented, 1 if demented, -1 if no group matching the file could be found.
  """

  filePattern = r"(OAS2_[0-9]{4}_MR[0-9]{1})"
  r_match = re.match(filePattern, filename)
  split = df[df["MRI ID"]==r_match.groups()[0]]["Group"].values
  if len(split) == 0:
     return -1
  else:
     return split[0]


def toRGB(data):
  """
  Function for converting a numpy array to the proper format to be saved as an RGB image.

  Parameters
  ---------
  data : numpy.ndarray
      Array of data to be converted to image
  """

  x, y = data.shape[:2]
  data = (data-data.min())/(data.max()-data.min())
  img_arr = np.empty(shape=(x,y,4))
  img_arr[:, :, :3] = data
  img_arr[:, :, 3] = 1.
  return img_arr

def cropImg(img_array):
   """
   Crop the image array to a height of 240. All other dimensions are unchanged

   Parameters:
      img_array (np.ndarray) : numpy.ndarray of the original image

   Returns:
      out (np.ndarray) : Cropped image
   """
   img_array = img_array[:240, :, :]
   return img_array

def getImgSplit(filename, split_df):
  """
   Get the split (testing, training, or validation) of the sample with the filename provided

   Parameters:
      filename (str): Name of the file
      df (pandas.DataFrame): DataFrame containing the list of MRI IDs and their splits

   Returns:
      out: str of the split or -1 if no split matching the file could be found
  """
  filePattern = r"(OAS2_[0-9]{4}_MR[0-9]{1})"
  r_match = re.match(filePattern, filename)
  split = split_df[split_df["MRI ID"]==r_match.groups()[0]]["Split"].values
  if len(split) == 0:
     return -1
  else:
     return split[0]

def convertToJPG(nii_dir, jpg_dir, split_df, sliceStart, numSlices=1, spacing=2):
    """
    Convert .nii files from the nii_dir directory to jpg images of various slices in the jpg_dir, and save them according to their TVT split set and group.

    Parameters:
      nii_dir (str): Source directory containing .nii files
      jpg_dir (str): Destination directory to save .jpg images into
      split_df (pandas.DataFrame): DataFrame containing the MRI ID and Split set for each sample
      sliceStart (int): Transverse slice number to begin slicing at
      numSlices (int): (Optional) Number of slices to extract per file. Default is 2.
      spacing (int): (Optional) Number of transverse slices between each extracted slice. Default is 2.

   Returns:
      out (tuple): Shape of the images extracted
    """

    mult = 2
    i = 0
    shape = (0,0,0,0)



    if not os.path.exists(jpg_dir):
       os.makedirs(jpg_dir)

    for root, dir, files in os.walk(nii_dir):

        for f in files:
            fbase, fext = os.path.splitext(f)
            if fext == ".nii":
                i += 1
                fname = os.path.join(root, f)
                img = nib.load(fname)
                for i in range(numSlices):
                  data = img.get_fdata()[sliceStart+i*mult,:,:]
                  img_arr = cropImg(toRGB(data))
                  shape = img_arr.shape
                  print(fbase)
                  split=getImgSplit(fbase, split_df)
                  group=getImgGroup(fbase, split_df)
                  if split!=-1 and group!=-1:
                    if False:
                      jpg_name = os.path.join(jpg_dir, split, f'{fbase.replace(".nifti","")}_{sliceStart+i*mult}.jpg')
                    else:
                       jpg_name = os.path.join(jpg_dir, split, f'class_{group}', f'{fbase.replace(".nifti","")}_{sliceStart+i*mult}.jpg')
                    plt.imsave(jpg_name, img_arr)

    return shape

# %%
# Get normalized data
df = pd.read_excel(os.getenv("NORMTAB"))

# If SPLITTVT == 1, make a new split set and save it.
# Otherwise, use an existing split set that's already been saved.
if os.getenv("SPLITTVT") == "1":
  df_split = makeTVTSplit(df)
  df_split.to_excel(os.getenv("SPLITTAB"))
else:
  df_split = pd.read_excel(os.getenv("SPLITTAB"))

# Get the destination directory to save the .jpg files
# If the directory doesn't exist, make it
jpg_dir = os.getenv("JPG")
if not os.path.exists(os.path.join(jpg_dir, "test")):
   os.makedirs(os.path.join(jpg_dir, "test"))

# See if the split set directories exist in the .jpg destination directory
# If not, make them
for split in ["validate", "train", "test"]:
   if not os.path.exists(os.path.join(jpg_dir, split, "class_0")):
      os.makedirs(os.path.join(jpg_dir, split, "class_0"))
   if not os.path.exists(os.path.join(jpg_dir, split, "class_1")):
      os.makedirs(os.path.join(jpg_dir, split, "class_1"))

# Set default data shape
data_shape = (240, 128, 4)

# If CONVERTJPG == 1, convert the .nii files to .jpg files
if os.getenv("CONVERTJPG") == "1":
   print("convert")
   data_shape = convertToJPG(nii_dir, jpg_dir, df_split, 80, int(os.getenv("NUMSLICES")), 2)
# Out:
# convert
# OAS2_0001_MR1_F1.nifti
# OAS2_0001_MR1_F1.nifti
# OAS2_0001_MR1_F1.nifti
# OAS2_0001_MR1_F1.nifti
# OAS2_0001_MR1_F2.nifti
# OAS2_0001_MR1_F2.nifti
# OAS2_0001_MR1_F2.nifti
# OAS2_0001_MR1_F2.nifti
# OAS2_0001_MR2_F1.nifti
# OAS2_0001_MR2_F1.nifti
# OAS2_0001_MR2_F1.nifti
# OAS2_0001_MR2_F1.nifti
# OAS2_0001_MR2_F2.nifti
# OAS2_0001_MR2_F2.nifti
# OAS2_0001_MR2_F2.nifti
# OAS2_0001_MR2_F2.nifti
# OAS2_0002_MR1_F1.nifti
# OAS2_0002_MR1_F1.nifti
# OAS2_0002_MR1_F1.nifti
# OAS2_0002_MR1_F1.nifti
# OAS2_0002_MR1_F2.nifti
# OAS2_0002_MR1_F2.nifti
# OAS2_0002_MR1_F2.nifti
# OAS2_0002_MR1_F2.nifti
# OAS2_0002_MR2_F1.nifti
# OAS2_0002_MR2_F1.nifti
# OAS2_0002_MR2_F1.nifti
# OAS2_0002_MR2_F1.nifti
# OAS2_0002_MR2_F2.nifti
# OAS2_0002_MR2_F2.nifti
# OAS2_0002_MR2_F2.nifti
# OAS2_0002_MR2_F2.nifti
# OAS2_0004_MR1_F1.nifti
# OAS2_0004_MR1_F1.nifti
# OAS2_0004_MR1_F1.nifti
# OAS2_0004_MR1_F1.nifti
# OAS2_0004_MR1_F2.nifti
# OAS2_0004_MR1_F2.nifti
# OAS2_0004_MR1_F2.nifti
# OAS2_0004_MR1_F2.nifti
# OAS2_0004_MR2_F1.nifti
# OAS2_0004_MR2_F1.nifti
# OAS2_0004_MR2_F1.nifti
# OAS2_0004_MR2_F1.nifti
# OAS2_0004_MR2_F2.nifti
# OAS2_0004_MR2_F2.nifti
# OAS2_0004_MR2_F2.nifti
# OAS2_0004_MR2_F2.nifti
# OAS2_0005_MR1_F1.nifti
# OAS2_0005_MR1_F1.nifti
# OAS2_0005_MR1_F1.nifti
# OAS2_0005_MR1_F1.nifti
# OAS2_0106_MR1_F2.nifti
# OAS2_0106_MR1_F2.nifti
# OAS2_0106_MR1_F2.nifti
# OAS2_0106_MR1_F2.nifti
# OAS2_0106_MR2_F1.nifti
# OAS2_0106_MR2_F1.nifti
# OAS2_0106_MR2_F1.nifti
# OAS2_0106_MR2_F1.nifti
# OAS2_0106_MR2_F2.nifti
# OAS2_0106_MR2_F2.nifti
# OAS2_0106_MR2_F2.nifti
# OAS2_0106_MR2_F2.nifti
# OAS2_0108_MR1_F1.nifti
# OAS2_0108_MR1_F1.nifti
# OAS2_0108_MR1_F1.nifti
# OAS2_0108_MR1_F1.nifti
# OAS2_0108_MR1_F2.nifti
# OAS2_0108_MR1_F2.nifti
# OAS2_0108_MR1_F2.nifti
# OAS2_0108_MR1_F2.nifti
# OAS2_0108_MR2_F1.nifti
# OAS2_0108_MR2_F1.nifti
# OAS2_0108_MR2_F1.nifti
# OAS2_0108_MR2_F1.nifti
# OAS2_0108_MR2_F2.nifti
# OAS2_0108_MR2_F2.nifti
# OAS2_0108_MR2_F2.nifti
# OAS2_0108_MR2_F2.nifti
# OAS2_0109_MR1_F1.nifti
# OAS2_0109_MR1_F1.nifti
# OAS2_0109_MR1_F1.nifti
# OAS2_0109_MR1_F1.nifti
# OAS2_0109_MR1_F2.nifti
# OAS2_0109_MR1_F2.nifti
# OAS2_0109_MR1_F2.nifti
# OAS2_0109_MR1_F2.nifti
# OAS2_0109_MR2_F1.nifti
# OAS2_0109_MR2_F1.nifti
# OAS2_0109_MR2_F1.nifti
# OAS2_0109_MR2_F1.nifti
# OAS2_0109_MR2_F2.nifti
# OAS2_0109_MR2_F2.nifti
# OAS2_0109_MR2_F2.nifti
# OAS2_0109_MR2_F2.nifti
# OAS2_0111_MR1_F1.nifti
# OAS2_0111_MR1_F1.nifti
# OAS2_0111_MR1_F1.nifti
# OAS2_0111_MR1_F1.nifti
# OAS2_0111_MR1_F2.nifti
# OAS2_0111_MR1_F2.nifti
# OAS2_0111_MR1_F2.nifti
# OAS2_0111_MR1_F2.nifti
# OAS2_0111_MR2_F1.nifti
# OAS2_0111_MR2_F1.nifti
# OAS2_0111_MR2_F1.nifti
# OAS2_0111_MR2_F1.nifti
# OAS2_0111_MR2_F2.nifti
# OAS2_0111_MR2_F2.nifti
# OAS2_0111_MR2_F2.nifti
# OAS2_0111_MR2_F2.nifti
# OAS2_0112_MR2_F1.nifti
# OAS2_0112_MR2_F1.nifti
# OAS2_0112_MR2_F1.nifti
# OAS2_0112_MR2_F1.nifti
# OAS2_0112_MR2_F2.nifti
# OAS2_0112_MR2_F2.nifti
# OAS2_0112_MR2_F2.nifti
# OAS2_0112_MR2_F2.nifti
# OAS2_0113_MR1_F1.nifti
# OAS2_0113_MR1_F1.nifti
# OAS2_0113_MR1_F1.nifti
# OAS2_0113_MR1_F1.nifti
# OAS2_0113_MR1_F2.nifti
# OAS2_0113_MR1_F2.nifti
# OAS2_0113_MR1_F2.nifti
# OAS2_0113_MR1_F2.nifti
# OAS2_0185_MR2_F2.nifti
# OAS2_0185_MR2_F2.nifti
# OAS2_0185_MR2_F2.nifti
# OAS2_0185_MR2_F2.nifti
# OAS2_0186_MR1_F1.nifti
# OAS2_0186_MR1_F1.nifti
# OAS2_0186_MR1_F1.nifti
# OAS2_0186_MR1_F1.nifti
# OAS2_0186_MR1_F2.nifti
# OAS2_0186_MR1_F2.nifti
# OAS2_0186_MR1_F2.nifti
# OAS2_0186_MR1_F2.nifti
# OAS2_0186_MR2_F1.nifti
# OAS2_0186_MR2_F1.nifti
# OAS2_0186_MR2_F1.nifti
# OAS2_0186_MR2_F1.nifti
# OAS2_0186_MR2_F2.nifti
# OAS2_0186_MR2_F2.nifti
# OAS2_0186_MR2_F2.nifti
# OAS2_0186_MR2_F2.nifti

# %% [markdown]
# # Model Training

# %%
import keras
from keras import layers
from keras import ops
from keras import Sequential
import tensorflow as tf
import SimpleITK as sitk
# Out:
# 2025-04-13 22:31:07.353806: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-13 22:31:07.548347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744605067.619222  150142 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744605067.636908  150142 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744605067.788024  150142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744605067.788055  150142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744605067.788057  150142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744605067.788058  150142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-13 22:31:07.802571: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# If training a new model, set up the base and model format
if os.getenv("TRAINMODEL") == "1":
  # Make the ResNet-50 base
  resnet_base = keras.applications.ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=(data_shape[0], data_shape[1], 3),
    pooling=True
  )

  # Don't train the ResNet-50 base
  resnet_base.trainable = False

  # Set up the OAS-52 layers
  model = Sequential([
    resnet_base,
    layers.Flatten(),
    layers.Dense(426, activation='relu'),
    layers.Dense(426, activation='leaky_relu'),
    layers.Dense(2, activation='softmax')
  ])

  # Compile the model
  model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
  )

# %%
# Make the training and validation datasets for Keras
# Both datasets are set up to use binary labels
def makeKerasTVTDatasets(batchSize):
  # Make the training dataset using the .jpg files in the "JPG/train" directory
  dset_train = keras.preprocessing.image_dataset_from_directory(
    directory=os.path.join(os.getenv("JPG"),"train"),
    seed=73,
    image_size=data_shape[:2],
    batch_size=batchSize,
    label_mode='binary')

  # Make the validation dataset using the .jpg files in the "JPG/validate" directory
  dset_validate = keras.preprocessing.image_dataset_from_directory(
    directory=os.path.join(os.getenv("JPG"),"validate"),
    seed=73,
    image_size=data_shape[:2],
    batch_size=batchSize,
    label_mode='binary')

  return dset_train, dset_validate

# Make the datasets, setting the batch size to 4.
# The batch size can be adjusted depending on the computing power of the
# machine being used.
dset_train, dset_validate= makeKerasTVTDatasets(4)
# Out:
# Found 1856 files belonging to 2 classes.
# I0000 00:00:1744605071.707932  150142 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2270 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 192 files belonging to 2 classes.

# %%
# Ensure there is at least 1 GPU available to utilize
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# If training a new model, train the model using history.
if os.getenv("TRAINMODEL") == "1":
  model.summary()

  # Train the model
  history = model.fit(dset_train, validation_data=dset_validate, epochs=15)

  if os.getenv("SAVEMODEL") == "1":
    # Save the model
    model.save("oas2-model.keras")

# Otherwise, load in an existing model.
else:

  # Load in an existing model
  model = keras.saving.load_model("oas-52-model.keras", compile=False)
  # Compile the model
  model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
  )
  # Print a summary of its architecture
  model.summary()


# Get the testing dataset
dset_test = keras.preprocessing.image_dataset_from_directory(
  directory=os.path.join(os.getenv("JPG"),"test"),
  seed=73,
  image_size=data_shape[:2],
  batch_size=4,
  label_mode='binary')
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 8, 4, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1856)           │   121,636,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 426)            │       791,082 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 116)            │        49,532 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           234 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 146,065,232 (557.19 MB)
#  Trainable params: 122,477,520 (467.21 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Found 280 files belonging to 2 classes.

# %% [markdown]
# # Making Predictions

# %%
if os.getenv("MAKEPREDICTIONS") =="1":
  predictions = []
  fileList = []
  mriID = []
  groups = []
  slice = []
  df_old = df.copy(deep=True)
  conf = []
  shap_acc  = []
  i = 0


  for root, dir, files in os.walk(os.path.join(os.getenv("JPG"), "test")):
    for f in files:

      g = getImgGroup(f, df)  # Get the group the image belongs to

      # Load the image and convert it to a usable format
      img = keras.preprocessing.image.load_img(os.path.join(root, f), target_size=data_shape[:3])
      img_arr = keras.preprocessing.image.img_to_array(img)
      img_arr = tf.expand_dims(img_arr, 0)

      # Collect extra data to be included alongside the predictions
      groups += [g]
      slice += [f[-6:-4]]
      mriID += [f[:13]]
      fileList += [f]

      # Make the prediction
      p = model.predict(img_arr)
      conf += [abs(p[0][0]-p[0][1])]  # Calculate the confidence of the prediction
      predictions += [np.argmax(p)]   # Use the argument index containing the largest value as the prediction

      # Update progress bar
      print(f'{i:2d} ({i*100./280.:.2f}%)')
      i += 1

  # Save predictions as a DataFrame
  df_predictions = pd.DataFrame({"MRI ID": mriID, "File": fileList, "Slice": slice, "Group": groups, "Prediction": predictions, "Confidence":conf})

  # For each prediction, record if it is true or false
  tf_a = []
  for index, row in df_predictions.iterrows():
    p = row["Prediction"]
    g = row["Group"]
    tf_a += [1 if g == p else 0]

  df_predictions["TF"] = tf_a

  # Save the predictions to an excel spreadsheet
  df_predictions.to_excel(os.getenv("PREDICTTAB"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  0 (0.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  1 (0.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  2 (0.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  3 (1.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#  4 (1.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  5 (1.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  6 (2.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  7 (2.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#  8 (2.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  9 (3.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 10 (3.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 11 (3.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 12 (4.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 13 (4.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 14 (5.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 15 (5.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 16 (5.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 17 (6.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 18 (6.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 19 (6.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 20 (7.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 21 (7.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 22 (7.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 23 (8.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 24 (8.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 25 (8.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 26 (9.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 27 (9.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 28 (10.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 29 (10.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 30 (10.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 31 (11.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 32 (11.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 33 (11.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 34 (12.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 35 (12.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 36 (12.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 37 (13.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 38 (13.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 39 (13.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 40 (14.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 41 (14.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 42 (15.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 43 (15.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 44 (15.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 45 (16.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 46 (16.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 47 (16.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 48 (17.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 49 (17.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 50 (17.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 51 (18.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 52 (18.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 53 (18.93%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 54 (19.29%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 55 (19.64%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 56 (20.00%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 57 (20.36%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 58 (20.71%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 59 (21.07%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 60 (21.43%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 61 (21.79%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 62 (22.14%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 63 (22.50%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 64 (22.86%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 65 (23.21%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 66 (23.57%)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#